# %%
from transformers import pipeline

print("Loading BERT sentiment pipeline...\n")

classifier = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")

texts = [
    "This product works amazingly well and I love it.",
    "The service was terrible and I will not come back."
]

results = classifier(texts)

print("--- RESULTS ---")
for text, result in zip(texts, results):
    label = result["label"]
    confidence = result["score"]

    print(f"Text: '{text}'")
    print(f"Prediction: {label} (Confidence: {confidence:.2%})\n")
# Out:
# Loading BERT sentiment pipeline...
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/953 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/669M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/201 [00:00<?, ?it/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# --- RESULTS ---
# Text: 'This product works amazingly well and I love it.'
# Prediction: 5 stars (Confidence: 92.60%)
#
# Text: 'The service was terrible and I will not come back.'
# Prediction: 1 star (Confidence: 84.43%)
